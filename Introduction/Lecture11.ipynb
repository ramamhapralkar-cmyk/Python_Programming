# %%
#Define class : Parent class bank
class bank:
    def __init__(self,acct_no,acct_holder,
                 age,gender,email_id,
                 address,mobile_no,
                 user_id,passcode):
        
        self.acct_no=acct_no
        self.acct_holder=acct_holder
        self.age=age
        self.gender=gender
        self.email_id=email_id
        self.address=address
        self.mobile_no=mobile_no
        self.__user_id=user_id
        self.__passcode=passcode
        
#Define method : credit
    def credit_info(self,amount,balance):
        self.amount=amount
        self.balance=balance



    def debit_info(self,amount,balance):
        self.amount=amount
        self.balance=balance
        

    def balance_info(self):
        pass

# %%
#define child class : saving_Acct
class saving_acct(bank):


#Define constructor
    def __init__(self,interest_rate,tenure):
        super().__init__(acct_no,acct_holder,
                 age,gender,email_id,
                 address,mobile_no,
                 user_id,passcode)
        
        self.interest_rate = interest_rate
        self.tenure = tenure
        
#Define method : credit_info
    def credit_info(self,amount,balance = 10000):
        self.amount=amount
        self.balance=balance

        print(f'the actual balance is {self.balance}')
        print(f'the credited amount is {self.amount}')
        print(f'the balance after credit is {self.balance + self.amount}')

#Define method : debit_info
    def debit_info(self,amount,balance = 10000):
      if (user_id.lower() == 'rama123') and (passcode == 'rama@20'):
        self.amount=amount
        self.balance=balance

        print(f'the actual balance is {self.balance}')
        print(f'the debited amount is {self.amount}')
        print(f'the balance after debit is {self.balance - self.amount}')
      else:
        print('Invalid user_id or passcode. Access denied.')

# %%
#taking user input

acct_no = input("Enter account number: ")   
acct_holder = input("Enter account holder name: ")
age = int(input("Enter age: "))
gender = input("Enter gender: ")
email = input("Enter email id: ")
address = input("Enter address: ")
mobile_no = input("Enter mobile number: ")
user_id = input("Enter user id: ")
passcode = input("Enter passcode: ")
amount = float(input("Enter the amount: "))
balance = float(input("Enter the balance: "))

# %%
#Define object
email_id = email
tjsb_1 = saving_acct(8, 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 #Define object
# ----> 2 tjsb_1 = saving_acct(8,5)
#
# Cell In[35], line 8, in saving_acct.__init__(self, interest_rate, tenure)
#       6     def __init__(self,interest_rate,tenure):
#       7         super().__init__(acct_no,acct_holder,
# ----> 8                  age,gender,email_id,
#       9                  address,mobile_no,
#      10                  user_id,passcode)
#      11
#
# NameError: name 'email_id' is not defined

# %%
tjsb_1.credit_info(amount,balance)
print(rama)
# Out:
# None

# %%
tjsb_1.credit_info(amount,balance)
print(tjsb_1.debit_info(amount,balance))
# Out:
# None

# %%
from abc import abc , abstractmethod

class bank(abc):

    @abstractmethod
    def credit_info(self):
        pass    

    @abstractmethod
    def debit_info(self):
        pass

    @abstractmethod
    def balance_info(self):
        pass

# %%
class saving_acct(bank):

    def credit_info(self):
        print('credit info')

    def debit_info(self):
        print('debit info')

    def balance_info(self):
        print('balance info')
